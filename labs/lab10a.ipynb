# %% [markdown]
# # Lab 10a: on Colab
#
# TODO:
# - Click on the link, open with Colab, and save it as your own copy: <a href="https://drive.google.com/file/d/1bXWY8PXtGBW3SS1IbokD-BLSlwM5h4JZ/view?usp=sharing"> Colab Link</a>
# - After finishing it, download the ipynb and upload it to canvas as before.
